# %% [markdown]
# ## Setup

# %%
import pandas as pd
import logging 
import sys
import os
sys.path.insert(0,'./src')


from src.utils.logger import sys_logger

os.makedirs("./final_data", exist_ok=True)

# %% [markdown]
# ## Landing Zone to Staging

# %%
from src.utils.splitter import split_files

split_files()
# Out:
# [splitter.py:9]                 Files in landing zone: ['customer_20241016.csv', 'products_20241016.json', 'sales_20241016.txt']
# [splitter.py:14]                customer_20241016.csv matched with customer
# [splitter.py:17]                customer_20241016.csv moved to ./data/customer/
# [splitter.py:14]                products_20241016.json matched with product
# [splitter.py:17]                products_20241016.json moved to ./data/product/
# [splitter.py:14]                sales_20241016.txt matched with sales
# [splitter.py:17]                sales_20241016.txt moved to ./data/sales/

# %% [markdown]
# ## Staging to Tables

# %%
from src.utils.ingestion import run_ingestion

run_ingestion()
# Out:
# [watermark.py:8]                Reading watermark table from ./watermark.parquet
# [watermark.py:14]               Watermark table has 21 rows
# [ingestion.py:12]               Loading customer data
# [watermark.py:18]               Getting last run date for customer
# [watermark.py:24]               Last run date for customer is 2024-10-15 00:00:00
# [files.py:10]                   Getting files to process from ./data/customer/
# [files.py:14]                   Found 1 files to process
# [ingestion.py:19]               Processing customer_20241016.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241016.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 12370 rows
# [dataframes.py:49]              Processing file with 7321 records.
# [dataframes.py:82]              Detected 1062 old records and 1450 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 13820 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 7321 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 7321, 'error_rows': 0, 'process_time': Timestamp('2024-11-17 03:08:57.784638'), 'file_date': Timestamp('2024-10-16 00:00:00'), 'file_id': '838e9b11-24a1-46bf-8ff4-2a0d779d9043', 'file_name': 'customer_20241016.csv'}
# [watermark.py:40]               Watermark table now has 22 rows
# [files.py:22]                   Saving file with 22 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241016.csv
# [ingestion.py:12]               Loading sales data
# [watermark.py:18]               Getting last run date for sales
# [watermark.py:24]               Last run date for sales is 2024-10-15 00:00:00
# [files.py:10]                   Getting files to process from ./data/sales/
# [files.py:14]                   Found 1 files to process
# [ingestion.py:19]               Processing sales_20241016.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241016.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 63773 rows
# [dataframes.py:49]              Processing file with 11395 records.
# [dataframes.py:112]             Detected 0 changes and 11395 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 75168 rows to ./final_data/sales.parquet
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[126], line 3
#       1 from src.utils.ingestion import run_ingestion
# ----> 3 run_ingestion()
#
# File ~\Desktop\4d-python-assessment_solution\src\utils\ingestion.py:22, in run_ingestion()
#      20 date = get_file_date(file)
#      21 df = read_func(location + file, **config.get('read_args', {}))
# ---> 22 stats = process_data(source_name, df, config, date)
#      23 stats['file_name'] = file
#      24 watermark_table = update_watermark_table(watermark_table, stats)
#
# File ~\Desktop\4d-python-assessment_solution\src\utils\dataframes.py:154, in process_data(source_name, dataframe, config, date)
#     144     #TODO: save error records to a file
#     146 new_table = apply_scd2(
#     147     current_table,
#     148     clean_records,
#    (...)
#     151     is_full,
#     152 )
# --> 154 save_file(get_save_filename(source_name), new_table)
#     156 stats = {
#     157     "source": source_name,
#     158     "processed_rows": len(clean_records),
#    (...)
#     162     "file_id": str(uuid4()),
#     163 }
#     165 sys_logger.info(f"Processed {len(clean_records)} records for {source_name}")
#
# File ~\Desktop\4d-python-assessment_solution\src\utils\files.py:23, in save_file(filepath, dataframe)
#      21 def save_file(filepath, dataframe):
#      22     sys_logger.info(f"Saving file with {len(dataframe)} rows to {filepath}")
# ---> 23     dataframe.to_parquet(filepath, index=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parquet.py:190, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     187 if index is not None:
#     188     from_pandas_kwargs["preserve_index"] = index
# --> 190 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     192 if df.attrs:
#     193     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\table.pxi:4525, in pyarrow.lib.Table.from_pandas()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\array.pxi:345, in pyarrow.lib.array()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\array.pxi:85, in pyarrow.lib._ndarray_to_array()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowInvalid: ("Could not convert 'ERROR' with type str: tried to convert to double", 'Conversion failed for column total_price with type object')

# %% [markdown]
# ## Report Generation

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### Customer Growth

# %%
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()

data = []
for date in sorted(dates):
    snapshot = customers[(customers['effective_from'] <= date) & (customers['expiry_date'] > date)]
    data.append({'date': date, 'count': len(snapshot)})

df = pd.DataFrame(data)
df.plot(x='date', y='count')
plt.title('Customer Growth')
plt.xlabel('Date')
plt.ylabel('Number of Customers')
plt.show()

# %%
customers.dtypes
# Out:
# is_current                     bool
# expiry_date          datetime64[ns]
# effective_from       datetime64[ns]
# customer_id                   int64
# hash                         uint64
# first_name                   object
# last_name                    object
# gender                       object
# email                        object
# membership_status            object
# address                      object
# phone_number                 object
# date_of_birth                object
# job                          object
# company                      object
# city                         object
# state                        object
# country                      object
# language                     object
# dtype: object

# %% [markdown]
# ### Sales By Membership

# %%
# Sales By Members
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()
sales = pd.read_parquet('./final_data/sales.parquet')
merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
data = merged.groupby(['sale_date', 'membership_status'])['total_price'].sum().unstack().fillna(0)

data.plot()
plt.title('Sales by Membership Status')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### Product Sale Breakdown

# %%
# pivot of most popular products over time from members vs non-members

products = pd.read_parquet('./final_data/product.parquet')
customers = pd.read_parquet('./final_data/customer.parquet')
sales = pd.read_parquet('./final_data/sales.parquet')

merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
merged_with_products = merged.merge(products, on='product_id', how='left')
data = merged_with_products.groupby(['sale_date', 'membership_status', 'name'])['total_price'].sum().unstack().fillna(0)
data
# Out:
# name                              Camera  External Hard Drive  Headphones  \
# sale_date  membership_status
# 2024-10-09 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-10 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-11 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-12 active                   0.00                 0.00   542564.00
#            inactive                 0.00                 0.00  1028280.00
# 2024-10-13 active             1912712.40                 0.00   546459.20
#            inactive           3572453.16                 0.00  1053483.20
# 2024-10-14 active             2191213.92            143835.64   590544.04
#            inactive           3262410.24            237151.36  1028406.56
# 2024-10-15 active             1905392.70            144721.08   557222.40
#            inactive           3307258.20            229886.16   890265.60
#
# name                               Laptop     Monitor      Mouse     Printer  \
# sale_date  membership_status
# 2024-10-09 active              7714256.20  1425283.65  205094.40  1388914.80
#            inactive           16059291.36  3232253.43  481219.20  2960967.10
# 2024-10-10 active              6033176.45  1316356.72  180747.63  1140371.26
#            inactive           13102433.40  2879737.56  332764.32  2472595.02
# 2024-10-11 active              5935608.00  1181432.00  173135.76  1155834.75
#            inactive           10684094.40  2231773.60  315731.36  2439908.10
# 2024-10-12 active              5280251.34  1255896.88  167447.28  1133237.07
#            inactive            9652723.08  2266911.36  302211.00  2124191.79
# 2024-10-13 active              4290997.62  1222725.00  151603.20  1278061.40
#            inactive            8423324.91  2163420.00  250145.28  2018991.59
# 2024-10-14 active              4090971.50  1045593.36  127227.66  1179916.22
#            inactive            6839297.50  1805872.32  228927.44  1955488.92
# 2024-10-15 active              3683285.62  1110422.04  156149.07  1074436.44
#            inactive            6248117.26  1670183.97  231034.79  1704604.44
#
# name                              Router  Smartphone  Smartwatch     Tablet
# sale_date  membership_status
# 2024-10-09 active             1356263.16        0.00        0.00       0.00
#            inactive           2758824.46        0.00        0.00       0.00
# 2024-10-10 active             1218046.83        0.00   533694.66       0.00
#            inactive           2198976.78        0.00  1072222.26       0.00
# 2024-10-11 active             1110109.28  2913344.85   488637.60       0.00
#            inactive           1983107.84  4937994.10  1000088.10       0.00
# 2024-10-12 active              922285.98  2713591.55   531843.30       0.00
#            inactive           1627122.42  5344715.05   885710.28       0.00
# 2024-10-13 active              833729.96  2549503.60   448796.70       0.00
#            inactive           1531708.50  4846424.80   960468.30       0.00
# 2024-10-14 active              850611.58  2531520.25   425252.52       0.00
#            inactive           1298721.97  4124345.40   791182.98       0.00
# 2024-10-15 active              711252.92  2425675.30   386894.04  277844.45
#            inactive           1223078.36  4177334.20   695503.50  490363.64

# %%
data.to_csv('./final_results/product_sale_breakdown.csv')

# %%
merged_with_products

# %% [markdown]
# ## Ticket MIDP-307

# %%
filtered_df = merged_with_products[merged_with_products['sale_date'] <= '2024-10-15']
top_customers = filtered_df.groupby('customer_id')['quantity'].sum().reset_index()
top_10_customers = top_customers.sort_values(by='quantity', ascending=False).head(10)
top_10_customers
# Out:
#              customer_id  quantity
# 3031  416636781440851074     851.0
# 746   105568439268969136     797.0
# 6483  883037698491635653     786.0
# 5977  811136600265466851     728.0
# 1845  261985261414427932     727.0
# 3511  477720798267676546     694.0
# 334    47453050786199672     681.0
# 6674  908236561118101324     675.0
# 6594  897154383584823481     644.0
# 1114  156786189949779706     636.0

# %%
top_10_customers.to_csv('./final_results/sales_report.csv')

# %%
filtered_df_active = merged_with_products[(merged_with_products['sale_date'] <= '2024-10-15') & (merged_with_products['membership_status'] == 'active')]
top_customers_active = filtered_df_active.groupby('customer_id')['quantity'].sum().reset_index()
top_10_customers_active = top_customers_active.sort_values(by='quantity', ascending=False).head(10)
top_10_customers_active
# Out:
#             customer_id  quantity
# 413  416636781440851074     851.0
# 89   105568439268969136     797.0
# 914  883037698491635653     786.0
# 836  811136600265466851     728.0
# 250  261985261414427932     727.0
# 482  477720798267676546     694.0
# 35    47453050786199672     681.0
# 944  908236561118101324     675.0
# 931  897154383584823481     644.0
# 146  156786189949779706     636.0

# %%
top_10_customers_active.to_csv('./final_results/sales_report_active_member.csv')
